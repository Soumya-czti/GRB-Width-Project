# %%
from astromodels.functions.function import (
    Function1D,
    FunctionMeta,
    ModelAssertionViolation,
)
from astropy import units as astropy_units
import numpy as np
import math
# %matplotlib inline
import matplotlib.pyplot as plt
from past.utils import old_div
np.seterr(all="ignore")


from threeML import *
from threeML.io.package_data import get_path_of_data_file

import os
import warnings
warnings.simplefilter("ignore")
try:
    from threeML.config.config import threeML_config
    _has_threeml = True

except ImportError:

    _has_threeml = False
# Out:
# 21:04:48 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=966172;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=120791;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=412078;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=903961;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
# 21:04:49 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=478948;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=584117;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
# 21:04:50 INFO      Starting 3ML!                                                                     ]8;id=938535;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=196863;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#39\39]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=3775;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=848255;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=752364;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=892368;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#41\41]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=326758;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=14923;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#44\44]8;;\
# 21:04:50 WARNING   ROOT minimizer not available                                                ]8;id=409812;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=430187;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=620112;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=591806;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=474713;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=868673;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
# 21:04:51 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=422713;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=885714;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=627912;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=192056;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=428446;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=453604;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=221423;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=254454;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=683328;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=755758;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %%
def bandfunc(x, K, alpha, beta, E0, piv):

    n = x.shape[0]
    out = np.empty(n)

    break_point = (alpha - beta) * E0

    factor_ab = np.exp(beta - alpha) * math.pow(break_point / piv, alpha - beta)

    for idx in range(n):

        if x[idx] < break_point:
            out[idx] = K * math.pow(x[idx] / piv, alpha) * np.exp(-x[idx] / E0)

        else:

            out[idx] = K * factor_ab * math.pow(x[idx] / piv, beta)

    return out

# %%
class Bandnew(Function1D, metaclass=FunctionMeta):
    r"""
    description :

        Band model from Band et al., 1993, parametrized with the peak energy

    latex : $K \begin{cases} \left(\frac{x}{piv}\right)^{\alpha} \exp \left(-\frac{(2+\alpha) x}{x_{p}}\right) & x \leq (\alpha-\beta) \frac{x_{p}}{(\alpha+2)} \\ \left(\frac{x}{piv}\right)^{\beta} \exp (\beta-\alpha)\left[\frac{(\alpha-\beta) x_{p}}{piv(2+\alpha)}\right]^{\alpha-\beta} &x>(\alpha-\beta) \frac{x_{p}}{(\alpha+2)} \end{cases} $

    parameters :

        K :

            desc : Differential flux at the pivot energy
            initial value : 1e-4
            min : 1e-50
            is_normalization : True
            transformation : log10

        alpha :

            desc : low-energy photon index
            initial value : -1.0
            min : -1.5
            max : 3

        xp :

            desc : peak in the x * x * N (nuFnu if x is a energy)
            initial value : 500
            min : 10
            transformation : log10

        beta :

            desc : high-energy photon index
            initial value : -2.1
            min : -5.0
            max : -2.1

        piv :

            desc : pivot energy
            initial value : 100.0
            fix : yes
    """
    def _set_units(self, x_unit, y_unit):
        self.K.unit = y_unit

   
        self.xp.unit = x_unit

        self.piv.unit = x_unit

        self.alpha.unit = astropy_units.dimensionless_unscaled
        self.beta.unit = astropy_units.dimensionless_unscaled

    def evaluate(self, x, K, alpha, xp, beta, piv):
        E0 = xp/(2 + alpha)

        if alpha < beta:
            alpha = beta
            log.warning("Alpha is currently less than beta. Setting alpha = beta.")
            # raise ModelAssertionViolation("Alpha cannot be less than beta")

        if isinstance(x, astropy_units.Quantity):
            alpha_ = alpha.value
            beta_ = beta.value
            K_ = K.value
            E0_ = E0.value
            piv_ = piv.value
            x_ = x.value

            unit_ = self.y_unit
            
        else:
            unit_ = 1.0
            alpha_, beta_, K_, piv_, x_, E0_ = alpha, beta, K, piv, x, E0

        return bandfunc(x_, K_, alpha_, beta_, E0_, piv_) * unit_

# %%
cpp_spectrum = Bandnew()

# %%
p = '/home/rishabh/GRB/GRB220426285/current' 

source_interval = '0.863-12.5'  
background_interval = '-100--20, 20-100' 

fluence_plugins = []
time_series = {}

gbm_detectors = ['n0','na']  

for det in gbm_detectors:
    cspec_file = f'{p}/glg_cspec_{det}_bn220426285_v00.pha'
    tte_file = f'{p}/glg_tte_{det}_bn220426285_v00.fit'
    gbm_rsp = f'{p}/glg_cspec_{det}_bn220426285_v01.rsp2'

    ts_cspec = TimeSeriesBuilder.from_gbm_cspec_or_ctime(
        f'{det}_cspec', cspec_or_ctime_file=cspec_file, rsp_file=gbm_rsp
    )

    ts_cspec.set_background_interval('-100--20','20-100')
    ts_cspec.save_background(f"{det}_bkg.h5", overwrite=True)

    ts_tte = TimeSeriesBuilder.from_gbm_tte(
        f'{det}_tte',
        tte_file=tte_file,
        rsp_file=gbm_rsp,
        restore_background=f"{det}_bkg.h5",
    )

    time_series[det] = ts_tte

    ts_tte.set_active_time_interval('0.863-12.5')

    ts_tte.view_lightcurve(-40, 100)

    fluence_plugin = ts_tte.to_spectrumlike()

    if det.startswith("b"): 
        fluence_plugin.set_active_measurements("250-30000")
    else: 
        fluence_plugin.set_active_measurements("9-900")

    fluence_plugin.rebin_on_background(1.0)
    fluence_plugins.append(fluence_plugin)
# Out:
# 21:05:22 WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 1) ]8;id=388503;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=515098;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
# 21:05:23 WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=335082;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=457711;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=564403;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=307750;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
# Loading PHAII Spectra:   0%|                           | 0/2837 [00:00<?, ?it/s]
# 21:05:25 WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 1) ]8;id=715258;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=163943;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=257356;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=493768;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=742573;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=872222;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 2) ]8;id=957317;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=344724;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=540244;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=105670;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=306986;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=341721;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 3) ]8;id=158374;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=40859;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=667350;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=679865;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=307669;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=220192;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 4) ]8;id=421654;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=263549;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=110003;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=103149;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=848563;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=885887;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 5) ]8;id=248133;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=584084;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=443838;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=980240;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=627056;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=574351;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
# 21:05:26 WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 6) ]8;id=962709;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=437176;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=699347;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=313628;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=955192;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=701911;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 7) ]8;id=553547;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=756693;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=187476;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=545020;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=588565;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=991627;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 8) ]8;id=595120;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=809819;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=618965;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=100088;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=658022;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=768817;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 9) ]8;id=340862;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=443432;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=720495;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=510261;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=179932;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=922668;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=761053;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=155944;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   10) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=703454;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=113846;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=871601;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=628739;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=349469;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=176322;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   11) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=523914;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=260552;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=82661;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=604017;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=552491;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=791592;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   12) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=611572;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=73464;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=959632;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=881449;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=672669;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=752026;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   13) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=103446;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=499455;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=757141;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=291865;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=571327;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=345127;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   14) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=429006;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=277495;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=480794;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=667217;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=575180;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=683196;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   15) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=885346;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=100298;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=744932;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=97015;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=737622;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=812959;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   16) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=539337;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=280674;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=374103;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=306388;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
# 21:05:27 WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=170551;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=415963;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   17) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=131010;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=678067;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=669597;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=252432;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=306360;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=518589;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   18) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=220787;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=97464;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=636139;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=710113;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=518265;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=782400;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
# Finding best polynomial Order:   0%|                      | 0/4 [00:00<?, ?it/s]
# 21:05:29 INFO      Auto-determined polynomial order: 0                                ]8;id=422037;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/binned_spectrum_series.py\binned_spectrum_series.py]8;;\:]8;id=310782;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/binned_spectrum_series.py#389\389]8;;\
# Fitting GBM_NAI_00 background:   0%|                    | 0/128 [00:00<?, ?it/s]
# 21:05:41 INFO      None 0-order polynomial fit with the mle method                               ]8;id=425185;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py\time_series.py]8;;\:]8;id=76573;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py#458\458]8;;\
#          INFO      Saved fitted background to n0_bkg.h5                                         ]8;id=376100;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py\time_series.py]8;;\:]8;id=269945;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py#1064\1064]8;;\
#          INFO      Saved background to n0_bkg.h5                                         ]8;id=262061;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=128474;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#471\471]8;;\
#          WARNING   The TTE file                                                                      ]8;id=637287;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/gbm_data.py\gbm_data.py]8;;\:]8;id=976031;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/gbm_data.py#43\43]8;;\
#                   /home/rishabh/GRB/GRB220426285/current/glg_tte_n0_bn220426285_v00.fit contains
#                   duplicate time tags and is thus invalid. Contact the FSSC
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 1) ]8;id=769883;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=477331;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=873369;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=267403;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=760249;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=892529;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 2) ]8;id=80493;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=902270;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=559398;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=223677;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=795529;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=750431;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 3) ]8;id=393431;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=642818;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=940157;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=322765;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=855406;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=851967;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 4) ]8;id=898884;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=911592;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=9423;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=933928;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
# 21:05:42 WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=830910;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=116478;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 5) ]8;id=552504;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=633242;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=947778;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=206545;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=547721;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=432196;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 6) ]8;id=598650;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=32716;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=152049;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=820409;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=169820;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=130835;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 7) ]8;id=374946;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=503543;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=238581;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=895836;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=910743;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=599538;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.567999839782715)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 8) ]8;id=701277;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=5537;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=317256;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=992784;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
# ...
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=881082;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=890309;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=320200;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=618159;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   12) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=715975;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=65609;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=79815;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=60476;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=296951;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=475337;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   13) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=444321;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=23436;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=503203;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=101690;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=271491;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=610758;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   14) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=354505;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=540085;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=835652;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=277135;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=572884;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=674342;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   15) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=33067;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=237003;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=793267;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=590864;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=729015;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=508288;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   16) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=768151;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=117634;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=502591;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=315558;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=718545;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=540868;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   17) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=252719;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=25978;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=337577;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=689061;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX',    ]8;id=288978;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=794506;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   18) not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#          WARNING   No TLMIN keyword found. This DRM does not follow OGIP standards. Assuming        ]8;id=156373;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=948851;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#611\611]8;;\
#                   TLMIN=1
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=141574;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=547815;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=874549;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=597481;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          INFO      Successfully restored fit from na_bkg.h5                              ]8;id=664534;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=324235;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#171\171]8;;\
# 21:06:08 WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=648073;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=547912;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (3.690000057220459)
#          INFO      Interval set to 0.863-12.5 for na_tte                                 ]8;id=704457;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=209962;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#290\290]8;;\
#          INFO      Auto-probed noise models:                                                    ]8;id=93683;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=320042;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#490\490]8;;\
#          INFO      - observation: poisson                                                       ]8;id=486552;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=107535;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#491\491]8;;\
#          INFO      - background: gaussian                                                       ]8;id=858067;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=208252;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#492\492]8;;\
#          INFO      Range 9-900 translates to channels 5-124                                    ]8;id=454193;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=212968;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#1247\1247]8;;\
#          INFO      Now using 120 bins                                                          ]8;id=432461;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=378394;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#1739\1739]8;;\

# %%
cpp_spectrum = Bandnew()
cpp_spectrum.alpha.prior = Uniform_prior(
lower_bound=-1.5, upper_bound=1)
cpp_spectrum.beta.prior = Uniform_prior(
    lower_bound=-5, upper_bound=-2.1
)
cpp_spectrum.xp.prior = Log_normal(mu=2, sigma=1)
cpp_spectrum.xp.bounds = (None,None)
cpp_spectrum.K.prior = Log_uniform_prior(
    lower_bound=1e-3, upper_bound=1e1
)
cpp_spectrum.piv = 100.0
cpp_spectrum.piv.fix = True
# Out:
# 21:06:13 WARNING   We have set the min_value of Bandnew.xp to 1e-99 because there was a postive    ]8;id=485903;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=679896;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#                   transform
#          WARNING   We have set the min_value of Bandnew.xp to 1e-99 because there was a postive    ]8;id=1058;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=975943;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#                   transform

# %%
from threeML import PointSource

ps = PointSource("grb", 0, 0, spectral_shape=cpp_spectrum)
model = Model(ps)

bayes = BayesianAnalysis(model, DataList(*fluence_plugins))
bayes.set_sampler("dynesty_nested", share_spectrum=False)
# Out:
# 21:06:16 INFO      sampler set to dynesty_nested                                           ]8;id=710751;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/bayesian_analysis.py\bayesian_analysis.py]8;;\:]8;id=80322;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/bayesian_analysis.py#202\202]8;;\

# %%
fig = display_spectrum_model_counts(bayes, min_rate=1.5, step=False)

# %%
bayes.sampler.setup(n_live_points=500)
bayes.sample()
# Out:
# 11805it [02:43, 72.15it/s, +500 | bound: 40 | nc: 1 | ncall: 47510 | eff(%): 26.175 | loglstar:   -inf < -1686.591 <    inf | logz: -1709.454 +/-  0.213 | dlogz:  0.001 >  0.509]
# 21:09:22 INFO      fit restored to maximum of posterior                                         ]8;id=797447;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/sampler_base.py\sampler_base.py]8;;\:]8;id=208586;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/sampler_base.py#178\178]8;;\
#          INFO      fit restored to maximum of posterior                                         ]8;id=598915;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/sampler_base.py\sampler_base.py]8;;\:]8;id=758721;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/sampler_base.py#178\178]8;;\
# Maximum a posteriori probability (MAP) point:
#                                                        result             unit
# parameter
# grb.spectrum.main.Bandnew.K         (9.59 -0.4 +0.19) x 10^-1  1 / (keV s cm2)
# grb.spectrum.main.Bandnew.alpha      (-2.4 -2.7 +1.4) x 10^-2
# grb.spectrum.main.Bandnew.xp     (1.404 -0.010 +0.018) x 10^2              keV
# grb.spectrum.main.Bandnew.beta              -3.28 -0.12 +0.07
# Values of -log(posterior) at the minimum:
#         -log(posterior)
# n0_tte      -848.405007
# na_tte      -858.497347
# total      -1706.902354
# Values of statistical measures:
#         statistical measures
# AIC              3421.974199
# BIC              3435.743895
# DIC              3401.334001
# PDIC                3.921264
# log(Z)           -742.406639

# %%
bayes.restore_median_fit()
fig = display_spectrum_model_counts(bayes, min_rate=20)
# Out:
# 21:09:36 INFO      fit restored to median of posterior                                          ]8;id=167375;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/sampler_base.py\sampler_base.py]8;;\:]8;id=138102;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/bayesian/sampler_base.py#164\164]8;;\
