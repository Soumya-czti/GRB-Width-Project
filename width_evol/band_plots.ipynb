# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
# %matplotlib notebook
from matplotlib.ticker import ScalarFormatter
import time

import bandn
import band

# %%
er = np.logspace(0,5,num=501) #in keV

beta = np.arange(-9.0,-2.1,0.1)
alp = np.arange(-1.5,3.0,0.01)
ep = np.arange(10,1500,10)
wd = np.arange(0.5,5.0,0.1)

epiv = 100.0

param_old = [-0.5,300,-3.45,epiv]
param_new = [-0.5,300,0.65,epiv,-3.45]

# %%
path = '/home/soumya/work.dir/GRB/width_studies/width_evol/output/'

# %%
font_ax = {'family': 'serif', 'size': 18}

ls = ['-','--','-.',':','-']
sc = ['^','o','d','s']
clr = ['black','teal','darkred','blue','darkorchid','pink']

# %%
b = []

a = [0.829743,0.419357,0.239926,0.353766,0.262757,0.262828,0.196971,0.130308,0.0080464]
w = [0.664040,0.749695,0.707557,0.692799,0.708054,0.693050,0.707503,0.731381,0.742704]
e = [156.865,180.795,180.868,130.229,131.475,124.015,109.506,89.9406,74.8615]

for i in range(len(a)):
    param2 = [a[i],e[i],w[i],epiv,-3.5]
    #param2[2] = width[i]
    #param2[4] = beta[i]
    xx = bandn.bandn(param2,er)
    b.append(xx[1])
    #spec_new.append(xx[0])mbb_plots_width

# %%
print(b)
# Out:
# [-3.2890625, -3.0234375, -3.6171875, -3.5859375, -3.5546875, -4.0078125, -3.8046875, -3.4921875, -3.6796875]

# %%
width =[]
spec_old = []
param1 = param_old

for i in range(len(beta)):
    param1[2] = beta[i]
    xx = band.band(param1,er)
    width.append(xx[1])
    spec_old.append(xx[0])

# %%
betan =[]
spec_new = []
param2 = param_new

for i in range(len(width)):
    param2[2] = width[i]
    param2[4] = beta[i]
    xx = bandn.bandn(param2,er)
    betan.append(xx[1])
    spec_new.append(xx[0])mbb_plots_width

# %%
fig1 = plt.figure()
plt.plot(beta,betan,ls='--',marker='o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ene = (er[1:]+er[:-1])/2.0
plt.plot(ene,spec_old[50],ls='--',lw=4)
plt.plot(ene,spec_new[50])
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
