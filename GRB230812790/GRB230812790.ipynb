# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np


np.seterr(all="ignore")
#from jupyterthemes import jtplot

#jtplot.style(context="talk", fscale=1, ticks=True, grid=False)
#plt.style.use("mike")

from threeML import *
from threeML.io.package_data import get_path_of_data_file

import os
import warnings
warnings.simplefilter("ignore")
# Out:
# 01:48:21 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=209364;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=761665;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=378493;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=795008;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
# ...

# %%
p = '/home/rishabh/Documents/bn230812790/current'
cspec_file = ('{0}/glg_cspec_n7_bn230812790_v00.pha'.format(p))
tte_file = ('{0}/glg_tte_n7_bn230812790_v04.fit'.format(p))
gbm_rsp = ('{0}/glg_cspec_n7_bn230812790_v02.rsp2'.format(p))


gbm_cspec = TimeSeriesBuilder.from_gbm_cspec_or_ctime('nai7_cspec',
                                                      cspec_or_ctime_file=cspec_file,
                                                      rsp_file=gbm_rsp)

gbm_tte = TimeSeriesBuilder.from_gbm_tte('nai7_tte',
                                          tte_file=tte_file,
                                          rsp_file=gbm_rsp)
# Out:
# 01:48:24 WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 1) ]8;id=382219;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=859523;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
#                   not found.")available: None 'EBOUNDS' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP
#                   MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX' 'SPECRESP MATRIX'
#                   'SPECRESP MATRIX' 'SPECRESP MATRIX'
# ...

# %%
gbm_tte.set_active_time_interval('0.3-5.1')
fig = gbm_tte.view_lightcurve(start=-10,stop=10,dt = 0.5)
# Out:
# 01:48:34 WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=327969;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=993349;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.5370001792907715)
#          INFO      Interval set to 0.3-5.1 for nai7_tte                                  ]8;id=370764;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=659529;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#290\290]8;;\

# %%
gbm_tte.set_background_interval('-100--15','20-150')
lightcurve  = gbm_tte.view_lightcurve(start=-10,stop=20)
lightcurve.savefig('lightcurve.pdf')
# Out:
# Finding best polynomial Order:   0%|                      | 0/4 [00:00<?, ?it/s]
# 01:48:40 INFO      Auto-determined polynomial order: 2                                            ]8;id=865392;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/event_list.py\event_list.py]8;;\:]8;id=999339;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/event_list.py#538\538]8;;\
# Fitting GBM_NAI_07 background:   0%|                    | 0/128 [00:00<?, ?it/s]
# 01:48:58 INFO      None 2-order polynomial fit with the mle method                               ]8;id=687778;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py\time_series.py]8;;\:]8;id=249545;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py#458\458]8;;\

# %%
gbm_tte.set_background_interval('-100--15','20-150',unbinned=False)
# Out:
# Finding best polynomial Order:   0%|                      | 0/4 [00:00<?, ?it/s]
# 01:49:02 INFO      Auto-determined polynomial order: 2                                            ]8;id=942458;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/event_list.py\event_list.py]8;;\:]8;id=825623;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/event_list.py#538\538]8;;\
# Fitting GBM_NAI_07 background:   0%|                    | 0/128 [00:00<?, ?it/s]
# 01:49:21 INFO      None 2-order polynomial fit with the mle method                               ]8;id=169689;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py\time_series.py]8;;\:]8;id=240235;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py#458\458]8;;\

# %%
gbm_tte.save_background('background_store_nai7',overwrite=True)
# Out:
#          INFO      Saved fitted background to background_store_nai7.h5                          ]8;id=907039;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py\time_series.py]8;;\:]8;id=683601;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/time_series/time_series.py#1064\1064]8;;\
#          INFO      Saved background to background_store_nai7                             ]8;id=264766;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=609349;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#471\471]8;;\

# %%
gbm_tte_reloaded = TimeSeriesBuilder.from_gbm_tte('nai7_tte',
                                          tte_file=tte_file,
                                          rsp_file=gbm_rsp,
                                          restore_background='background_store_nai7.h5')
# Out:
#          WARNING   The TTE file                                                                      ]8;id=469286;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/gbm_data.py\gbm_data.py]8;;\:]8;id=30626;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/gbm_data.py#43\43]8;;\
#                   /home/rishabh/Documents/bn230812790/current/glg_tte_n7_bn230812790_v04.fit
#                   contains duplicate time tags and is thus invalid. Contact the FSSC
#          WARNING   The default choice for MATRIX extension failed:KeyError("Extension ('MATRIX', 1) ]8;id=819039;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=946341;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#476\476]8;;\
# ...

# %%
fig = gbm_tte_reloaded.view_lightcurve(-50,150)

# %%
gbm_plugin = gbm_tte.to_spectrumlike()
# Out:
# 01:49:25 INFO      Auto-probed noise models:                                                    ]8;id=304359;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=953858;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#490\490]8;;\
#          INFO      - observation: poisson                                                       ]8;id=132214;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=704810;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/plugins/SpectrumLike.py#491\491]8;;\
# ...

# %%
gbm_plugin.display()
# Out:
#                                    0
# n. channels                      128
# total rate              22260.503631
# total bkg. rate          1272.461796
# total bkg. rate error       3.884118
# bkg. exposure               4.592888
# bkg. is poisson                False
# exposure                    4.592888
# is poisson                      True
# background                  profiled
# significance              584.529147
# src/bkg area ratio               1.0
# src/bkg exposure ratio           1.0
# src/bkg scale factor             1.0
# response                        None

# %%
gbm_tte.create_time_bins(start=0.3, stop=5.1, method='constant', dt=1.0)
gbm_tte.bins.display()
# Out:
#          INFO      Created 5 bins via constant                                           ]8;id=363022;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=42608;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#708\708]8;;\
#      Start     Stop  Duration  Midpoint
# 0  0.30002  1.30002       1.0   0.80002
# 1  1.30002  2.30002       1.0   1.80002
# 2  2.30002  3.30002       1.0   2.80002
# 3  3.30002  4.30002       1.0   3.80002
# 4  4.30002  5.30002       1.0   4.80002

# %%
gbm_tte.create_time_bins(start=0.3, stop=5.1, method='significance', sigma=30)
# Out:
# Binning by significance:   0%|                       | 0/102240 [00:00<?, ?it/s]
# 01:52:31 INFO      Created 479 bins via significance                                     ]8;id=937158;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=771304;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#708\708]8;;\

# %%
gbm_tte.bins.display()
# Out:
#         Start      Stop  Duration  Midpoint
# 0    0.300020  0.309196  0.009176  0.304608
# 1    0.309196  0.318830  0.009634  0.314013
# 2    0.318830  0.325814  0.006984  0.322322
# 3    0.325814  0.333110  0.007296  0.329462
# 4    0.333110  0.339662  0.006552  0.336386
# ..        ...       ...       ...       ...
# 474  4.299530  4.423722  0.124192  4.361626
# 475  4.423722  4.551896  0.128174  4.487809
# 476  4.551896  4.696494  0.144598  4.624195
# 477  4.696494  4.865026  0.168532  4.780760
# 478  4.865026  5.077726  0.212700  4.971376
#
# [479 rows x 4 columns]

# %%
gbm_tte.create_time_bins(start=0.3, stop=5.1, method='bayesblocks', p0=.01, use_background=True)
# Out:
# 01:54:35 INFO      Created 19 bins via bayesblocks                                       ]8;id=766408;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=270556;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#708\708]8;;\

# %%
gbm_tte.bins.display()
# Out:
#        Start      Stop  Duration  Midpoint
# 0   0.300020  0.380651  0.080631  0.340336
# 1   0.380651  0.467081  0.086430  0.423866
# 2   0.467081  0.846284  0.379203  0.656683
# 3   0.846284  1.079856  0.233572  0.963070
# 4   1.079856  1.282289  0.202433  1.181073
# 5   1.282289  1.285002  0.002713  1.283646
# 6   1.285002  1.726911  0.441909  1.505957
# 7   1.726911  1.837973  0.111062  1.782442
# 8   1.837973  1.995632  0.157659  1.916802
# 9   1.995632  2.135707  0.140075  2.065670
# 10  2.135707  2.410904  0.275197  2.273306
# 11  2.410904  2.821620  0.410716  2.616262
# 12  2.821620  3.076909  0.255289  2.949265
# 13  3.076909  3.309806  0.232897  3.193357
# 14  3.309806  3.525686  0.215880  3.417746
# 15  3.525686  3.740700  0.215014  3.633193
# 16  3.740700  4.096233  0.355533  3.918467
# 17  4.096233  4.629112  0.532879  4.362673
# 18  4.629112  5.099878  0.470766  4.864495

# %%
fig = gbm_tte.view_lightcurve(use_binner=True)

# %%
bad_bins = []
for i, w in enumerate(gbm_tte.bins.widths):

    if w < 5e-2:
        bad_bins.append(i)


edges = [gbm_tte.bins.starts[0]]

for i, b in enumerate(gbm_tte.bins):

    if i not in bad_bins:
        edges.append(b.stop)

starts = edges[:-1]
stops = edges[1:]


gbm_tte.create_time_bins(starts, stops, method="custom")
# Out:
# 01:54:36 INFO      Created 18 bins via custom                                            ]8;id=784347;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=216652;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#708\708]8;;\

# %%
pd.set_option('display.max_rows', None)
gbm_tte.bins.display()
# Out:
#        Start      Stop  Duration  Midpoint
# 0   0.300020  0.380651  0.080631  0.340336
# 1   0.380651  0.467081  0.086430  0.423866
# 2   0.467081  0.846284  0.379203  0.656683
# 3   0.846284  1.079856  0.233572  0.963070
# 4   1.079856  1.282289  0.202433  1.181073
# 5   1.282289  1.726911  0.444622  1.504600
# 6   1.726911  1.837973  0.111062  1.782442
# 7   1.837973  1.995632  0.157659  1.916802
# 8   1.995632  2.135707  0.140075  2.065670
# 9   2.135707  2.410904  0.275197  2.273306
# 10  2.410904  2.821620  0.410716  2.616262
# 11  2.821620  3.076909  0.255289  2.949265
# 12  3.076909  3.309806  0.232897  3.193357
# 13  3.309806  3.525686  0.215880  3.417746
# 14  3.525686  3.740700  0.215014  3.633193
# 15  3.740700  4.096233  0.355533  3.918467
# 16  4.096233  4.629112  0.532879  4.362673
# 17  4.629112  5.099878  0.470766  4.864495

# %%
fig = gbm_tte.view_lightcurve(use_binner=True)
# plt.axvline(x = 10.011611 , color = 'b', label = 'axvline - full height')
# plt.axvline(x = 11.243868 , color = 'b', label = 'axvline - full height')
plt.xlim(-10,20)
# Out:
# (-10.0, 20.0)

# %%
gbm_tte.write_pha_from_binner(
    file_name="out", overwrite=True, force_rsp_write=False
)  # if you need to write the RSP to a file. We try to choose the best option for you.
# Out:
# Creating plugins:   0%|                                  | 0/18 [00:00<?, ?it/s]
# 01:54:42 INFO      Selections saved to out                                               ]8;id=755017;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=672422;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#443\443]8;;\

# %%
my_plugins = gbm_tte.to_spectrumlike(from_bins=True)
# Out:
# Creating plugins:   0%|                                  | 0/18 [00:00<?, ?it/s]
# 01:54:46 WARNING   Minimum MC energy (5.0) is larger than minimum EBOUNDS energy                    ]8;id=438082;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py\response.py]8;;\:]8;id=129600;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/OGIP/response.py#140\140]8;;\
#                   (4.5370001792907715)
#          INFO      Interval set to 0.3-5.1 for nai7_tte                                  ]8;id=87079;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py\time_series_builder.py]8;;\:]8;id=923120;file:///home/rishabh/miniconda3/envs/threeml/lib/python3.9/site-packages/threeML/utils/data_builders/time_series_builder.py#290\290]8;;\

# %%
my_plugins,gbm_tte.bins.display()
# Out:
#        Start      Stop  Duration  Midpoint
# 0   0.300020  0.380651  0.080631  0.340336
# 1   0.380651  0.467081  0.086430  0.423866
# 2   0.467081  0.846284  0.379203  0.656683
# 3   0.846284  1.079856  0.233572  0.963070
# 4   1.079856  1.282289  0.202433  1.181073
# 5   1.282289  1.726911  0.444622  1.504600
# 6   1.726911  1.837973  0.111062  1.782442
# 7   1.837973  1.995632  0.157659  1.916802
# 8   1.995632  2.135707  0.140075  2.065670
# 9   2.135707  2.410904  0.275197  2.273306
# 10  2.410904  2.821620  0.410716  2.616262
# 11  2.821620  3.076909  0.255289  2.949265
# 12  3.076909  3.309806  0.232897  3.193357
# 13  3.309806  3.525686  0.215880  3.417746
# 14  3.525686  3.740700  0.215014  3.633193
# 15  3.740700  4.096233  0.355533  3.918467
# 16  4.096233  4.629112  0.532879  4.362673
# 17  4.629112  5.099878  0.470766  4.864495
# ([n. channels                        128
#   total rate                29387.389995
#   total bkg. rate            1272.465057
# ...
